# %%
import wandb
import pandas as pd

run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: emadmagdy7272 (emad_magdy). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.2
# Run data is saved locally in <code>/workspaces/nd0821-c2-build-model-workflow-starter/src/eda/wandb/run-20240621_200624-kpu5ozr2</code>
# Syncing run <strong><a href='https://wandb.ai/emad_magdy/nyc_airbnb/runs/kpu5ozr2' target="_blank">serene-hill-43</a></strong> to <a href='https://wandb.ai/emad_magdy/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/emad_magdy/nyc_airbnb' target="_blank">https://wandb.ai/emad_magdy/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/emad_magdy/nyc_airbnb/runs/kpu5ozr2' target="_blank">https://wandb.ai/emad_magdy/nyc_airbnb/runs/kpu5ozr2</a>

# %%
! conda install -c conda-forge ydata-profiling -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/nyc_airbnb_dev
#
#   added / updated specs:
#     - ydata-profiling
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     annotated-types-0.7.0      |     pyhd8ed1ab_0          18 KB  conda-forge
#     dacite-1.8.1               |     pyhd8ed1ab_0          19 KB  conda-forge
#     htmlmin-0.1.12             |     pyhca7485f_2          24 KB  conda-forge
#     imagehash-4.3.1            |     pyhd8ed1ab_0         294 KB  conda-forge
#     libllvm14-14.0.6           |       hcd5def8_4        30.0 MB  conda-forge
#     llvmlite-0.43.0            |  py312h9c5d478_0         3.3 MB  conda-forge
#     multimethod-1.11           |     pyhd8ed1ab_1          15 KB  conda-forge
#     networkx-3.3               |     pyhd8ed1ab_1         1.1 MB  conda-forge
#     numba-0.60.0               |  py312h83e6fd3_0         5.4 MB  conda-forge
#     patsy-0.5.6                |     pyhd8ed1ab_0         183 KB  conda-forge
#     phik-0.12.3                |  py312h5b9907d_1         632 KB  conda-forge
#     pybind11-abi-4             |       hd8ed1ab_3          10 KB  conda-forge
#     pydantic-2.7.4             |     pyhd8ed1ab_0         275 KB  conda-forge
#     pydantic-core-2.18.4       |  py312h4413252_0         1.6 MB  conda-forge
#     pywavelets-1.4.1           |  py312hc7c0aa3_1         3.6 MB  conda-forge
#     seaborn-base-0.13.2        |     pyhd8ed1ab_2         229 KB  conda-forge
#     statsmodels-0.14.2         |  py312h085067d_0        11.7 MB  conda-forge
#     tqdm-4.66.4                |     pyhd8ed1ab_0          87 KB  conda-forge
#     typeguard-4.3.0            |     pyhd8ed1ab_0          34 KB  conda-forge
#     visions-0.7.6              |     pyhd8ed1ab_1          65 KB  conda-forge
#     wordcloud-1.9.3            |  py312h98912ed_1         187 KB  conda-forge
#     ydata-profiling-4.8.3      |     pyhd8ed1ab_1         200 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        58.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   annotated-types    conda-forge/noarch::annotated-types-0.7.0-pyhd8ed1ab_0
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_0
#   dacite             conda-forge/noarch::dacite-1.8.1-pyhd8ed1ab_0
#   htmlmin            conda-forge/noarch::htmlmin-0.1.12-pyhca7485f_2
#   imagehash          conda-forge/noarch::imagehash-4.3.1-pyhd8ed1ab_0
#   libllvm14          conda-forge/linux-64::libllvm14-14.0.6-hcd5def8_4
#   llvmlite           conda-forge/linux-64::llvmlite-0.43.0-py312h9c5d478_0
#   multimethod        conda-forge/noarch::multimethod-1.11-pyhd8ed1ab_1
#   networkx           conda-forge/noarch::networkx-3.3-pyhd8ed1ab_1
#   numba              conda-forge/linux-64::numba-0.60.0-py312h83e6fd3_0
#   patsy              conda-forge/noarch::patsy-0.5.6-pyhd8ed1ab_0
#   phik               conda-forge/linux-64::phik-0.12.3-py312h5b9907d_1
#   pybind11-abi       conda-forge/noarch::pybind11-abi-4-hd8ed1ab_3
#   pydantic           conda-forge/noarch::pydantic-2.7.4-pyhd8ed1ab_0
#   pydantic-core      conda-forge/linux-64::pydantic-core-2.18.4-py312h4413252_0
#   pywavelets         conda-forge/linux-64::pywavelets-1.4.1-py312hc7c0aa3_1
#   seaborn-base       conda-forge/noarch::seaborn-base-0.13.2-pyhd8ed1ab_2
#   statsmodels        conda-forge/linux-64::statsmodels-0.14.2-py312h085067d_0
#   tqdm               conda-forge/noarch::tqdm-4.66.4-pyhd8ed1ab_0
#   typeguard          conda-forge/noarch::typeguard-4.3.0-pyhd8ed1ab_0
#   visions            conda-forge/noarch::visions-0.7.6-pyhd8ed1ab_1
#   wordcloud          conda-forge/linux-64::wordcloud-1.9.3-py312h98912ed_1
#   ydata-profiling    conda-forge/noarch::ydata-profiling-4.8.3-pyhd8ed1ab_1
#
#
#
# Downloading and Extracting Packages:
# libllvm14-14.0.6     | 30.0 MB   |                                       |   0%
# statsmodels-0.14.2   | 11.7 MB   |                                       |   0%
#
# numba-0.60.0         | 5.4 MB    |                                       |   0%
#
#
# pywavelets-1.4.1     | 3.6 MB    |                                       |   0%
#
#
#
# llvmlite-0.43.0      | 3.3 MB    |                                       |   0%
#
#
#
#
# pydantic-core-2.18.4 | 1.6 MB    |                                       |   0%
#
#
#
#
#
# networkx-3.3         | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
# phik-0.12.3          | 632 KB    |                                       |   0%
#
#
#
#
#
#
#
# imagehash-4.3.1      | 294 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# pydantic-2.7.4       | 275 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# seaborn-base-0.13.2  | 229 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# ydata-profiling-4.8. | 200 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# wordcloud-1.9.3      | 187 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# patsy-0.5.6          | 183 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tqdm-4.66.4          | 87 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# visions-0.7.6        | 65 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typeguard-4.3.0      | 34 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# htmlmin-0.1.12       | 24 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dacite-1.8.1         | 19 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# annotated-types-0.7. | 18 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# multimethod-1.11     | 15 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pybind11-abi-4       | 10 KB     |                                       |   0%
#
#
#
# llvmlite-0.43.0      | 3.3 MB    | 1                                     |   0%
#
#
# pywavelets-1.4.1     | 3.6 MB    | 1                                     |   0%
# libllvm14-14.0.6     | 30.0 MB   |                                       |   0%
#
# numba-0.60.0         | 5.4 MB    | 1                                     |   0%
# libllvm14-14.0.6     | 30.0 MB   | ####2                                 |  11%
#
# numba-0.60.0         | 5.4 MB    | #########################2            |  68%
#
#
#
#
# pydantic-core-2.18.4 | 1.6 MB    | 3                                     |   1%
#
#
#
#
#
# libllvm14-14.0.6     | 30.0 MB   | #######9                              |  21%
# statsmodels-0.14.2   | 11.7 MB   | ####################8                 |  56%
#
#
#
#
#
#
#
# imagehash-4.3.1      | 294 KB    | ##                                    |   5%
#
#
#
#
#
#
# phik-0.12.3          | 632 KB    | 9                                     |   3%
#
#
#
#
#
#
#
#
# pydantic-2.7.4       | 275 KB    | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 30.0 MB   | ###########9                          |  32%
# statsmodels-0.14.2   | 11.7 MB   | #################################1    |  90%
#
#
#
#
#
#
#
#
#
#
# ydata-profiling-4.8. | 200 KB    | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# wordcloud-1.9.3      | 187 KB    | ###1                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# patsy-0.5.6          | 183 KB    | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tqdm-4.66.4          | 87 KB     | ######7                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# visions-0.7.6        | 65 KB     | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typeguard-4.3.0      | 34 KB     | #################4                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 30.0 MB   | ################9                     |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dacite-1.8.1         | 19 KB     | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# multimethod-1.11     | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pybind11-abi-4       | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 30.0 MB   | ##########################9           |  73%
#
#
# pywavelets-1.4.1     | 3.6 MB    | ##################################### | 100%
#
#
# pywavelets-1.4.1     | 3.6 MB    | ##################################### | 100%
#
#
#
# llvmlite-0.43.0      | 3.3 MB    | ##################################### | 100%
#
#
#
# llvmlite-0.43.0      | 3.3 MB    | ##################################### | 100%
#
#
#
#
#
# networkx-3.3         | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
# networkx-3.3         | 1.1 MB    | ##################################### | 100%
#
#
#
#
# pydantic-core-2.18.4 | 1.6 MB    | ##################################### | 100%
#
#
#
#
# pydantic-core-2.18.4 | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# imagehash-4.3.1      | 294 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# imagehash-4.3.1      | 294 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# pydantic-2.7.4       | 275 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# pydantic-2.7.4       | 275 KB    | ##################################### | 100%
#
#
#
#
#
#
# phik-0.12.3          | 632 KB    | ##################################### | 100%
#
#
#
#
#
#
# phik-0.12.3          | 632 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# seaborn-base-0.13.2  | 229 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# seaborn-base-0.13.2  | 229 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# ydata-profiling-4.8. | 200 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# ydata-profiling-4.8. | 200 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# wordcloud-1.9.3      | 187 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# wordcloud-1.9.3      | 187 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# patsy-0.5.6          | 183 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# patsy-0.5.6          | 183 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tqdm-4.66.4          | 87 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tqdm-4.66.4          | 87 KB     | ##################################### | 100%
#
# numba-0.60.0         | 5.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typeguard-4.3.0      | 34 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typeguard-4.3.0      | 34 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# visions-0.7.6        | 65 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# htmlmin-0.1.12       | 24 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# visions-0.7.6        | 65 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# htmlmin-0.1.12       | 24 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# multimethod-1.11     | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dacite-1.8.1         | 19 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dacite-1.8.1         | 19 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pybind11-abi-4       | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 30.0 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
! pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from ipywidgets) (8.25.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.11 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.11-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.11 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.3-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 3.1 MB/s eta 0:00:00ta 0:00:01
# Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 5.5 MB/s eta 0:00:00ta 0:00:01
# Downloading widgetsnbextension-4.0.11-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 30.4 MB/s eta 0:00:00:00:01
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.3 jupyterlab-widgets-3.0.11 widgetsnbextension-4.0.11

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df)
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /opt/conda/envs/nyc_airbnb_dev/lib/python3.12/site-packages/ydata_profiling/model/correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Queens'')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %%
run.finish()
# Out:
# VBox(children=(Label(value='0.054 MB of 0.054 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">serene-hill-43</strong> at: <a href='https://wandb.ai/emad_magdy/nyc_airbnb/runs/kpu5ozr2' target="_blank">https://wandb.ai/emad_magdy/nyc_airbnb/runs/kpu5ozr2</a><br/> View project at: <a href='https://wandb.ai/emad_magdy/nyc_airbnb' target="_blank">https://wandb.ai/emad_magdy/nyc_airbnb</a><br/>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20240621_200624-kpu5ozr2/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
